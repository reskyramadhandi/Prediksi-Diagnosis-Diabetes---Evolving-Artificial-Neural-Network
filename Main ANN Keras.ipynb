# %%
# Memanggil Dependencies
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import sklearn
import keras
import tensorflow as tf      

from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

from numpy import ndarray
from sklearn.metrics import confusion_matrix, roc_curve, auc, roc_auc_score, accuracy_score, classification_report

RANDOM_SEED = 27

# %%
# Load dataset
df = pd.read_csv('input/diabetesPreProcessed.csv')

# Mengambil data pada kolom Outcome ke variabel target sebagai numpy Array
dftarget = df['Outcome']
target = dftarget.to_numpy()

# Menghapus kolom Outcome untuk mengambil data seluruh features
df = df.drop(columns=['Outcome'])

# Seluruh data features disimpan ke dalam variabel data sebagai numpy Array
data = df.to_numpy()

# %%
# Standarisasi Data
from sklearn.preprocessing import StandardScaler
s = StandardScaler()
data = s.fit_transform(data)

# %%
# Split Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=RANDOM_SEED)

# Mengubah data target menjadi array 2D
# y_train = y_train.reshape(-1, 1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (604, 8) (152, 8) (604,) (152,)

# %%
# Training Neural Network
import time
start = time.perf_counter()
np.random.seed(RANDOM_SEED)

# define model
model = Sequential()
model.add(Dense(16, input_dim=8, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
tf.keras.optimizers.SGD(lr=0.02)
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# fit model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=2000, verbose=0, callbacks=[es, mc])
# load the saved model
saved_model = load_model('best_model.h5')
# evaluate the model
_, train_acc = saved_model.evaluate(X_train, y_train, verbose=0)
_, test_acc = saved_model.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))

elapsed = time.perf_counter() - start
print('Elapsed %.3f seconds.' % elapsed)
# Out:
# Epoch 00001: val_accuracy improved from -inf to 0.56579, saving model to best_model.h5
#
# Epoch 00002: val_accuracy improved from 0.56579 to 0.64474, saving model to best_model.h5
#
# Epoch 00003: val_accuracy improved from 0.64474 to 0.75658, saving model to best_model.h5
#
# Epoch 00004: val_accuracy improved from 0.75658 to 0.76974, saving model to best_model.h5
#
# Epoch 00005: val_accuracy improved from 0.76974 to 0.77632, saving model to best_model.h5
#
# Epoch 00006: val_accuracy did not improve from 0.77632
#
# Epoch 00007: val_accuracy improved from 0.77632 to 0.78289, saving model to best_model.h5
#
# Epoch 00008: val_accuracy did not improve from 0.78289
#
# Epoch 00009: val_accuracy did not improve from 0.78289
#
# Epoch 00010: val_accuracy did not improve from 0.78289
#
# Epoch 00011: val_accuracy did not improve from 0.78289
#
# Epoch 00012: val_accuracy improved from 0.78289 to 0.78947, saving model to best_model.h5
#
# Epoch 00013: val_accuracy did not improve from 0.78947
#
# Epoch 00014: val_accuracy did not improve from 0.78947
#
# Epoch 00015: val_accuracy did not improve from 0.78947
#
# Epoch 00016: val_accuracy did not improve from 0.78947
#
# Epoch 00017: val_accuracy did not improve from 0.78947
#
# Epoch 00018: val_accuracy did not improve from 0.78947
#
# Epoch 00019: val_accuracy did not improve from 0.78947
#
# Epoch 00020: val_accuracy did not improve from 0.78947
#
# Epoch 00021: val_accuracy did not improve from 0.78947
#
# Epoch 00022: val_accuracy did not improve from 0.78947
#
# Epoch 00023: val_accuracy did not improve from 0.78947
#
# Epoch 00024: val_accuracy did not improve from 0.78947
#
# Epoch 00025: val_accuracy did not improve from 0.78947
#
# Epoch 00026: val_accuracy did not improve from 0.78947
#
# Epoch 00027: val_accuracy did not improve from 0.78947
#
# Epoch 00028: val_accuracy did not improve from 0.78947
#
# Epoch 00029: val_accuracy did not improve from 0.78947
#
# Epoch 00030: val_accuracy did not improve from 0.78947
#
# Epoch 00031: val_accuracy did not improve from 0.78947
#
# Epoch 00032: val_accuracy did not improve from 0.78947
#
# Epoch 00033: val_accuracy did not improve from 0.78947
#
# Epoch 00034: val_accuracy did not improve from 0.78947
#
# Epoch 00035: val_accuracy did not improve from 0.78947
#
# Epoch 00036: val_accuracy did not improve from 0.78947
#
# Epoch 00037: val_accuracy did not improve from 0.78947
#
# Epoch 00038: val_accuracy did not improve from 0.78947
#
# Epoch 00039: val_accuracy did not improve from 0.78947
#
# Epoch 00040: val_accuracy did not improve from 0.78947
#
# Epoch 00041: val_accuracy did not improve from 0.78947
#
# Epoch 00042: val_accuracy did not improve from 0.78947
#
# Epoch 00043: val_accuracy did not improve from 0.78947
#
# Epoch 00044: val_accuracy did not improve from 0.78947
#
# Epoch 00045: val_accuracy did not improve from 0.78947
#
# Epoch 00046: val_accuracy did not improve from 0.78947
#
# Epoch 00047: val_accuracy did not improve from 0.78947
#
# Epoch 00048: val_accuracy did not improve from 0.78947
#
# Epoch 00049: val_accuracy improved from 0.78947 to 0.79605, saving model to best_model.h5
#
# Epoch 00050: val_accuracy did not improve from 0.79605
#
# Epoch 00051: val_accuracy did not improve from 0.79605
#
# Epoch 00052: val_accuracy did not improve from 0.79605
#
# Epoch 00053: val_accuracy did not improve from 0.79605
#
# Epoch 00054: val_accuracy did not improve from 0.79605
#
# Epoch 00055: val_accuracy did not improve from 0.79605
#
# Epoch 00056: val_accuracy did not improve from 0.79605
#
# Epoch 00057: val_accuracy did not improve from 0.79605
#
# Epoch 00058: val_accuracy did not improve from 0.79605
#
# Epoch 00059: val_accuracy did not improve from 0.79605
#
# Epoch 00060: val_accuracy did not improve from 0.79605
#
# Epoch 00061: val_accuracy did not improve from 0.79605
#
# Epoch 00062: val_accuracy did not improve from 0.79605
#
# Epoch 00063: val_accuracy did not improve from 0.79605
#
# Epoch 00064: val_accuracy did not improve from 0.79605
#
# Epoch 00065: val_accuracy did not improve from 0.79605
#
# Epoch 00066: val_accuracy did not improve from 0.79605
#
# Epoch 00067: val_accuracy did not improve from 0.79605
#
# Epoch 00068: val_accuracy did not improve from 0.79605
#
# Epoch 00069: val_accuracy did not improve from 0.79605
#
# Epoch 00070: val_accuracy did not improve from 0.79605
#
# Epoch 00071: val_accuracy did not improve from 0.79605
#
# Epoch 00072: val_accuracy did not improve from 0.79605
#
# Epoch 00073: val_accuracy did not improve from 0.79605
#
# Epoch 00074: val_accuracy improved from 0.79605 to 0.80263, saving model to best_model.h5
#
# Epoch 00075: val_accuracy did not improve from 0.80263
#
# Epoch 00076: val_accuracy did not improve from 0.80263
#
# Epoch 00077: val_accuracy did not improve from 0.80263
#
# Epoch 00078: val_accuracy did not improve from 0.80263
#
# Epoch 00079: val_accuracy did not improve from 0.80263
#
# Epoch 00080: val_accuracy did not improve from 0.80263
#
# Epoch 00081: val_accuracy did not improve from 0.80263
#
# Epoch 00082: val_accuracy did not improve from 0.80263
#
# Epoch 00083: val_accuracy did not improve from 0.80263
#
# Epoch 00084: val_accuracy did not improve from 0.80263
#
# Epoch 00085: val_accuracy did not improve from 0.80263
#
# Epoch 00086: val_accuracy did not improve from 0.80263
#
# Epoch 00087: val_accuracy did not improve from 0.80263
#
# Epoch 00088: val_accuracy did not improve from 0.80263
#
# Epoch 00089: val_accuracy did not improve from 0.80263
#
# Epoch 00090: val_accuracy did not improve from 0.80263
#
# Epoch 00091: val_accuracy did not improve from 0.80263
#
# Epoch 00092: val_accuracy did not improve from 0.80263
#
# Epoch 00093: val_accuracy did not improve from 0.80263
#
# Epoch 00094: val_accuracy did not improve from 0.80263
#
# Epoch 00095: val_accuracy did not improve from 0.80263
#
# Epoch 00096: val_accuracy did not improve from 0.80263
#
# Epoch 00097: val_accuracy did not improve from 0.80263
#
# Epoch 00098: val_accuracy did not improve from 0.80263
#
# Epoch 00099: val_accuracy did not improve from 0.80263
#
# Epoch 00100: val_accuracy did not improve from 0.80263
#
# Epoch 00101: val_accuracy did not improve from 0.80263
#
# Epoch 00102: val_accuracy did not improve from 0.80263
#
# Epoch 00103: val_accuracy did not improve from 0.80263
#
# Epoch 00104: val_accuracy did not improve from 0.80263
#
# Epoch 00105: val_accuracy did not improve from 0.80263
#
# Epoch 00106: val_accuracy did not improve from 0.80263
#
# Epoch 00107: val_accuracy did not improve from 0.80263
#
# Epoch 00108: val_accuracy did not improve from 0.80263
#
# Epoch 00109: val_accuracy did not improve from 0.80263
#
# Epoch 00110: val_accuracy did not improve from 0.80263
#
# Epoch 00111: val_accuracy did not improve from 0.80263
#
# Epoch 00112: val_accuracy did not improve from 0.80263
#
# Epoch 00113: val_accuracy did not improve from 0.80263
#
# Epoch 00114: val_accuracy did not improve from 0.80263
#
# Epoch 00115: val_accuracy did not improve from 0.80263
#
# Epoch 00116: val_accuracy did not improve from 0.80263
#
# Epoch 00117: val_accuracy did not improve from 0.80263
#
# Epoch 00118: val_accuracy did not improve from 0.80263
#
# Epoch 00119: val_accuracy did not improve from 0.80263
#
# Epoch 00120: val_accuracy did not improve from 0.80263
#
# Epoch 00121: val_accuracy did not improve from 0.80263
#
# Epoch 00122: val_accuracy did not improve from 0.80263
#
# Epoch 00123: val_accuracy did not improve from 0.80263
#
# Epoch 00124: val_accuracy did not improve from 0.80263
#
# Epoch 00125: val_accuracy did not improve from 0.80263
#
# Epoch 00126: val_accuracy did not improve from 0.80263
#
# Epoch 00127: val_accuracy did not improve from 0.80263
#
# Epoch 00128: val_accuracy did not improve from 0.80263
#
# Epoch 00129: val_accuracy did not improve from 0.80263
#
# Epoch 00130: val_accuracy did not improve from 0.80263
#
# Epoch 00131: val_accuracy did not improve from 0.80263
#
# Epoch 00132: val_accuracy did not improve from 0.80263
#
# Epoch 00133: val_accuracy did not improve from 0.80263
#
# Epoch 00134: val_accuracy did not improve from 0.80263
#
# Epoch 00135: val_accuracy did not improve from 0.80263
#
# Epoch 00136: val_accuracy did not improve from 0.80263
#
# Epoch 00137: val_accuracy did not improve from 0.80263
#
# Epoch 00138: val_accuracy did not improve from 0.80263
#
# Epoch 00139: val_accuracy did not improve from 0.80263
#
# Epoch 00140: val_accuracy did not improve from 0.80263
#
# Epoch 00141: val_accuracy did not improve from 0.80263
# Epoch 00142: val_accuracy did not improve from 0.80263
#
# Epoch 00143: val_accuracy did not improve from 0.80263
#
# Epoch 00144: val_accuracy did not improve from 0.80263
#
# Epoch 00145: val_accuracy did not improve from 0.80263
#
# Epoch 00146: val_accuracy did not improve from 0.80263
#
# Epoch 00147: val_accuracy did not improve from 0.80263
#
# Epoch 00148: val_accuracy did not improve from 0.80263
#
# Epoch 00149: val_accuracy did not improve from 0.80263
#
# Epoch 00150: val_accuracy did not improve from 0.80263
#
# Epoch 00151: val_accuracy did not improve from 0.80263
#
# Epoch 00152: val_accuracy did not improve from 0.80263
#
# Epoch 00153: val_accuracy did not improve from 0.80263
#
# Epoch 00154: val_accuracy did not improve from 0.80263
#
# Epoch 00155: val_accuracy did not improve from 0.80263
#
# Epoch 00156: val_accuracy did not improve from 0.80263
#
# Epoch 00157: val_accuracy did not improve from 0.80263
#
# Epoch 00158: val_accuracy did not improve from 0.80263
#
# Epoch 00159: val_accuracy did not improve from 0.80263
#
# Epoch 00160: val_accuracy did not improve from 0.80263
#
# Epoch 00161: val_accuracy did not improve from 0.80263
#
# Epoch 00162: val_accuracy did not improve from 0.80263
#
# Epoch 00163: val_accuracy did not improve from 0.80263
#
# Epoch 00164: val_accuracy did not improve from 0.80263
#
# Epoch 00165: val_accuracy did not improve from 0.80263
#
# Epoch 00166: val_accuracy did not improve from 0.80263
#
# Epoch 00167: val_accuracy did not improve from 0.80263
#
# Epoch 00168: val_accuracy did not improve from 0.80263
#
# Epoch 00169: val_accuracy did not improve from 0.80263
#
# Epoch 00170: val_accuracy did not improve from 0.80263
#
# Epoch 00171: val_accuracy did not improve from 0.80263
#
# Epoch 00172: val_accuracy did not improve from 0.80263
#
# Epoch 00173: val_accuracy did not improve from 0.80263
#
# Epoch 00174: val_accuracy did not improve from 0.80263
#
# Epoch 00175: val_accuracy did not improve from 0.80263
#
# Epoch 00176: val_accuracy did not improve from 0.80263
#
# Epoch 00177: val_accuracy did not improve from 0.80263
#
# Epoch 00178: val_accuracy did not improve from 0.80263
#
# Epoch 00179: val_accuracy did not improve from 0.80263
#
# Epoch 00180: val_accuracy did not improve from 0.80263
#
# Epoch 00181: val_accuracy did not improve from 0.80263
#
# Epoch 00182: val_accuracy did not improve from 0.80263
#
# Epoch 00183: val_accuracy did not improve from 0.80263
#
# Epoch 00184: val_accuracy did not improve from 0.80263
#
# Epoch 00185: val_accuracy did not improve from 0.80263
#
# Epoch 00186: val_accuracy did not improve from 0.80263
#
# Epoch 00187: val_accuracy did not improve from 0.80263
#
# Epoch 00188: val_accuracy did not improve from 0.80263
#
# Epoch 00189: val_accuracy did not improve from 0.80263
#
# Epoch 00190: val_accuracy did not improve from 0.80263
#
# Epoch 00191: val_accuracy did not improve from 0.80263
#
# Epoch 00192: val_accuracy did not improve from 0.80263
#
# Epoch 00193: val_accuracy did not improve from 0.80263
#
# Epoch 00194: val_accuracy did not improve from 0.80263
#
# Epoch 00195: val_accuracy did not improve from 0.80263
#
# Epoch 00196: val_accuracy did not improve from 0.80263
#
# Epoch 00197: val_accuracy did not improve from 0.80263
#
# Epoch 00198: val_accuracy did not improve from 0.80263
#
# Epoch 00199: val_accuracy did not improve from 0.80263
#
# Epoch 00200: val_accuracy did not improve from 0.80263
#
# Epoch 00201: val_accuracy did not improve from 0.80263
#
# Epoch 00202: val_accuracy did not improve from 0.80263
#
# Epoch 00203: val_accuracy did not improve from 0.80263
#
# Epoch 00204: val_accuracy did not improve from 0.80263
#
# Epoch 00205: val_accuracy did not improve from 0.80263
#
# Epoch 00206: val_accuracy did not improve from 0.80263
#
# Epoch 00207: val_accuracy did not improve from 0.80263
#
# Epoch 00208: val_accuracy did not improve from 0.80263
#
# Epoch 00209: val_accuracy did not improve from 0.80263
#
# Epoch 00210: val_accuracy did not improve from 0.80263
#
# Epoch 00211: val_accuracy did not improve from 0.80263
#
# Epoch 00212: val_accuracy did not improve from 0.80263
#
# Epoch 00213: val_accuracy did not improve from 0.80263
#
# Epoch 00214: val_accuracy did not improve from 0.80263
#
# Epoch 00215: val_accuracy did not improve from 0.80263
#
# Epoch 00216: val_accuracy did not improve from 0.80263
#
# Epoch 00217: val_accuracy did not improve from 0.80263
#
# Epoch 00218: val_accuracy did not improve from 0.80263
#
# Epoch 00219: val_accuracy did not improve from 0.80263
#
# Epoch 00220: val_accuracy did not improve from 0.80263
#
# Epoch 00221: val_accuracy did not improve from 0.80263
#
# Epoch 00222: val_accuracy did not improve from 0.80263
#
# Epoch 00223: val_accuracy did not improve from 0.80263
#
# Epoch 00224: val_accuracy did not improve from 0.80263
#
# Epoch 00225: val_accuracy did not improve from 0.80263
#
# Epoch 00226: val_accuracy did not improve from 0.80263
#
# Epoch 00227: val_accuracy did not improve from 0.80263
#
# Epoch 00228: val_accuracy did not improve from 0.80263
#
# Epoch 00229: val_accuracy did not improve from 0.80263
#
# Epoch 00230: val_accuracy did not improve from 0.80263
#
# Epoch 00231: val_accuracy did not improve from 0.80263
#
# Epoch 00232: val_accuracy did not improve from 0.80263
#
# Epoch 00233: val_accuracy did not improve from 0.80263
#
# Epoch 00234: val_accuracy did not improve from 0.80263
#
# Epoch 00235: val_accuracy did not improve from 0.80263
#
# Epoch 00236: val_accuracy did not improve from 0.80263
#
# Epoch 00237: val_accuracy did not improve from 0.80263
#
# Epoch 00238: val_accuracy did not improve from 0.80263
#
# Epoch 00239: val_accuracy did not improve from 0.80263
#
# Epoch 00240: val_accuracy did not improve from 0.80263
#
# Epoch 00241: val_accuracy did not improve from 0.80263
#
# Epoch 00242: val_accuracy did not improve from 0.80263
#
# Epoch 00243: val_accuracy did not improve from 0.80263
#
# Epoch 00244: val_accuracy did not improve from 0.80263
#
# Epoch 00245: val_accuracy did not improve from 0.80263
#
# Epoch 00246: val_accuracy did not improve from 0.80263
#
# Epoch 00247: val_accuracy did not improve from 0.80263
#
# Epoch 00248: val_accuracy did not improve from 0.80263
#
# Epoch 00249: val_accuracy did not improve from 0.80263
#
# Epoch 00250: val_accuracy did not improve from 0.80263
#
# Epoch 00251: val_accuracy did not improve from 0.80263
#
# Epoch 00252: val_accuracy did not improve from 0.80263
#
# Epoch 00253: val_accuracy did not improve from 0.80263
#
# Epoch 00254: val_accuracy did not improve from 0.80263
#
# Epoch 00255: val_accuracy did not improve from 0.80263
#
# Epoch 00256: val_accuracy did not improve from 0.80263
#
# Epoch 00257: val_accuracy did not improve from 0.80263
#
# Epoch 00258: val_accuracy did not improve from 0.80263
#
# Epoch 00259: val_accuracy did not improve from 0.80263
#
# Epoch 00260: val_accuracy did not improve from 0.80263
#
# Epoch 00261: val_accuracy did not improve from 0.80263
#
# Epoch 00262: val_accuracy did not improve from 0.80263
#
# Epoch 00263: val_accuracy did not improve from 0.80263
#
# Epoch 00264: val_accuracy did not improve from 0.80263
#
# Epoch 00265: val_accuracy did not improve from 0.80263
#
# Epoch 00266: val_accuracy did not improve from 0.80263
#
# Epoch 00267: val_accuracy did not improve from 0.80263
#
# Epoch 00268: val_accuracy did not improve from 0.80263
#
# Epoch 00269: val_accuracy did not improve from 0.80263
#
# Epoch 00270: val_accuracy did not improve from 0.80263
#
# Epoch 00271: val_accuracy did not improve from 0.80263
#
# Epoch 00272: val_accuracy did not improve from 0.80263
#
# Epoch 00273: val_accuracy did not improve from 0.80263
#
# Epoch 00274: val_accuracy did not improve from 0.80263
#
# Epoch 00275: val_accuracy did not improve from 0.80263
#
# Epoch 00276: val_accuracy did not improve from 0.80263
#
# Epoch 00277: val_accuracy did not improve from 0.80263
#
# Epoch 00278: val_accuracy did not improve from 0.80263
#
# Epoch 00279: val_accuracy did not improve from 0.80263
#
# Epoch 00280: val_accuracy did not improve from 0.80263
#
# Epoch 00281: val_accuracy did not improve from 0.80263
#
# Epoch 00282: val_accuracy did not improve from 0.80263
#
# Epoch 00283: val_accuracy did not improve from 0.80263
#
# Epoch 00284: val_accuracy did not improve from 0.80263
#
# Epoch 00285: val_accuracy did not improve from 0.80263
#
# Epoch 00286: val_accuracy did not improve from 0.80263
#
# Epoch 00287: val_accuracy did not improve from 0.80263
#
# Epoch 00288: val_accuracy did not improve from 0.80263
#
# Epoch 00289: val_accuracy did not improve from 0.80263
#
# Epoch 00290: val_accuracy did not improve from 0.80263
#
# Epoch 00291: val_accuracy did not improve from 0.80263
#
# Epoch 00292: val_accuracy did not improve from 0.80263
# Epoch 00293: val_accuracy did not improve from 0.80263
#
# Epoch 00294: val_accuracy did not improve from 0.80263
#
# Epoch 00295: val_accuracy did not improve from 0.80263
#
# Epoch 00296: val_accuracy did not improve from 0.80263
#
# Epoch 00297: val_accuracy did not improve from 0.80263
#
# Epoch 00298: val_accuracy did not improve from 0.80263
#
# Epoch 00299: val_accuracy did not improve from 0.80263
#
# Epoch 00300: val_accuracy did not improve from 0.80263
#
# Epoch 00301: val_accuracy did not improve from 0.80263
#
# Epoch 00302: val_accuracy did not improve from 0.80263
#
# Epoch 00303: val_accuracy did not improve from 0.80263
#
# Epoch 00304: val_accuracy did not improve from 0.80263
#
# Epoch 00305: val_accuracy did not improve from 0.80263
#
# Epoch 00306: val_accuracy did not improve from 0.80263
#
# Epoch 00307: val_accuracy did not improve from 0.80263
#
# Epoch 00308: val_accuracy did not improve from 0.80263
#
# Epoch 00309: val_accuracy did not improve from 0.80263
#
# Epoch 00310: val_accuracy did not improve from 0.80263
#
# Epoch 00311: val_accuracy did not improve from 0.80263
#
# Epoch 00312: val_accuracy did not improve from 0.80263
#
# Epoch 00313: val_accuracy did not improve from 0.80263
#
# Epoch 00314: val_accuracy did not improve from 0.80263
#
# Epoch 00315: val_accuracy did not improve from 0.80263
#
# Epoch 00316: val_accuracy did not improve from 0.80263
#
# Epoch 00317: val_accuracy did not improve from 0.80263
#
# Epoch 00318: val_accuracy did not improve from 0.80263
#
# Epoch 00319: val_accuracy did not improve from 0.80263
#
# Epoch 00320: val_accuracy did not improve from 0.80263
#
# Epoch 00321: val_accuracy did not improve from 0.80263
#
# Epoch 00322: val_accuracy did not improve from 0.80263
#
# Epoch 00323: val_accuracy did not improve from 0.80263
#
# Epoch 00324: val_accuracy did not improve from 0.80263
#
# Epoch 00325: val_accuracy did not improve from 0.80263
#
# Epoch 00326: val_accuracy did not improve from 0.80263
#
# Epoch 00327: val_accuracy did not improve from 0.80263
#
# Epoch 00328: val_accuracy did not improve from 0.80263
#
# Epoch 00329: val_accuracy did not improve from 0.80263
#
# Epoch 00330: val_accuracy did not improve from 0.80263
#
# Epoch 00331: val_accuracy did not improve from 0.80263
#
# Epoch 00332: val_accuracy did not improve from 0.80263
#
# Epoch 00333: val_accuracy did not improve from 0.80263
#
# Epoch 00334: val_accuracy did not improve from 0.80263
#
# Epoch 00335: val_accuracy did not improve from 0.80263
#
# Epoch 00336: val_accuracy did not improve from 0.80263
#
# Epoch 00337: val_accuracy did not improve from 0.80263
#
# Epoch 00338: val_accuracy did not improve from 0.80263
#
# Epoch 00339: val_accuracy did not improve from 0.80263
#
# Epoch 00340: val_accuracy did not improve from 0.80263
#
# Epoch 00341: val_accuracy did not improve from 0.80263
#
# Epoch 00342: val_accuracy did not improve from 0.80263
#
# Epoch 00343: val_accuracy did not improve from 0.80263
#
# Epoch 00344: val_accuracy did not improve from 0.80263
#
# Epoch 00345: val_accuracy did not improve from 0.80263
#
# Epoch 00346: val_accuracy did not improve from 0.80263
#
# Epoch 00347: val_accuracy did not improve from 0.80263
#
# Epoch 00348: val_accuracy did not improve from 0.80263
#
# Epoch 00349: val_accuracy did not improve from 0.80263
#
# Epoch 00350: val_accuracy did not improve from 0.80263
#
# Epoch 00351: val_accuracy did not improve from 0.80263
#
# Epoch 00352: val_accuracy did not improve from 0.80263
#
# Epoch 00353: val_accuracy did not improve from 0.80263
#
# Epoch 00354: val_accuracy did not improve from 0.80263
#
# Epoch 00355: val_accuracy did not improve from 0.80263
# Epoch 00355: early stopping
# Train: 0.788, Test: 0.803
# Elapsed 7.801 seconds.

# %%
# Testing Neural Network
pred = saved_model.predict(X_test)
classsificationPreds = np.array([])
for i in pred:
    if i < 0.5:
        classsificationPreds = np.append(classsificationPreds, [0])
    else:
        classsificationPreds = np.append(classsificationPreds, [1])

# %%
# Confusion Matrix untuk set testing
print(confusion_matrix(y_test, classsificationPreds))
print(classification_report(y_test, classsificationPreds))
# Out:
# [[92 13]
#  [17 30]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       105
#            1       0.70      0.64      0.67        47
#
#     accuracy                           0.80       152
#    macro avg       0.77      0.76      0.76       152
# weighted avg       0.80      0.80      0.80       152
