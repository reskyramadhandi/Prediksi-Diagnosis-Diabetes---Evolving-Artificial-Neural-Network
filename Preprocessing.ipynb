# %%
# Import Dependencies
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_style('darkgrid')

# %% [markdown]
# Load Dataset

# %%
# Load dataset
df = pd.read_csv('input/diabetes.csv')
# Pratinjau data set
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## A. Kolom Pregnancies

# %%
df['Pregnancies'].describe()
# Out:
# count    768.000000
# mean       3.845052
# std        3.369578
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: Pregnancies, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['Pregnancies'],ax=axes[0],color='b')
axes[0].set_title('Distribution of Pregnancy',fontdict={'fontsize':8})
axes[0].set_xlabel('Pregnancy Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('Pregnancies',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %%
hitungcek = (df['Pregnancies'] >= 14).sum()
print("Data Kehamilan >= 14: ", hitungcek)
df = df.loc[df['Pregnancies'] < 14]
print(df['Pregnancies'].describe())
# Out:
# Data Kehamilan >= 14:  4
# count    764.000000
# mean       3.786649
# std        3.278714
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       13.000000
# Name: Pregnancies, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['Pregnancies'],ax=axes[0],color='b')
axes[0].set_title('Distribution of Pregnancy',fontdict={'fontsize':8})
axes[0].set_xlabel('Pregnancy Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('Pregnancies',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %% [markdown]
# ## B. Kolom Glucose

# %%
df['Glucose'].describe()
# Out:
# count    764.000000
# mean     120.776178
# std       31.946234
# min        0.000000
# 25%       99.000000
# 50%      117.000000
# 75%      140.000000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['Glucose'],ax=axes[0],color='b')
axes[0].set_title('Distribution of Glucose',fontdict={'fontsize':8})
axes[0].set_xlabel('Glucose Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('Glucose',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %%
glukosaNol = (df['Glucose'] == 0).sum()
print("Data Glucose 0 =", glukosaNol)
# Out:
# Data Glucose 0 = 5

# %%
df.Glucose = df.Glucose.replace(0,df.Glucose.mean())
print(df['Glucose'].describe())
# Out:
# count    764.000000
# mean     121.566598
# std       30.403080
# min       44.000000
# 25%       99.000000
# 50%      117.000000
# 75%      140.000000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['Glucose'],ax=axes[0],color='b')
axes[0].set_title('Distribution of Glucose',fontdict={'fontsize':8})
axes[0].set_xlabel('Glucose Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('Glucose',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %% [markdown]
# ## C. Kolom BloodPressure

# %%
df['BloodPressure'].describe()
# Out:
# count    764.000000
# mean      69.098168
# std       19.401789
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['BloodPressure'],ax=axes[0],color='b')
axes[0].set_title('Distribution of BloodPressure',fontdict={'fontsize':8})
axes[0].set_xlabel('BloodPressure Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('BloodPressure',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %%
# Tekanan darah = 0
bloodPressureNol = (df['BloodPressure'] == 0).sum()
print("Data BloodPressure 0 =", bloodPressureNol)

# Tekanan Darah 0 s.d. 40
bloodPressureRendah = df.query('BloodPressure > 0 and BloodPressure < 40')
bloodPressureRendah = bloodPressureRendah.BloodPressure.count()
print("Data BloodPressure 0 s.d. 40 =", bloodPressureRendah)

# Tekanan darah > 100
bloodPressureTinggi = (df['BloodPressure'] > 100).sum()
print("Data BloodPressure >100 =", bloodPressureTinggi)
# Out:
# Data BloodPressure 0 = 35
# Data BloodPressure 0 s.d. 40 = 4
# Data BloodPressure >100 = 13

# %%
df.BloodPressure = df.BloodPressure.replace(0,df.BloodPressure.mean())
print(df['BloodPressure'].describe())
# Out:
# count    764.000000
# mean      72.263660
# std       12.139999
# min       24.000000
# 25%       64.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
df = df.loc[df['BloodPressure'] >=40 ]
print(df['BloodPressure'].describe())
# Out:
# count    760.000000
# mean      72.483468
# std       11.780719
# min       40.000000
# 25%       64.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['BloodPressure'],ax=axes[0],color='b')
axes[0].set_title('Distribution of BloodPressure',fontdict={'fontsize':8})
axes[0].set_xlabel('BloodPressure Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('BloodPressure',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %%
print(df['BloodPressure'].describe())
# Out:
# count    760.000000
# mean      72.483468
# std       11.780719
# min       40.000000
# 25%       64.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %% [markdown]
# ## D. Kolom SkinThickness

# %%
df.SkinThickness.describe()
# Out:
# count    760.000000
# mean      20.430263
# std       15.976692
# min        0.000000
# 25%        0.000000
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: SkinThickness, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['SkinThickness'],ax=axes[0],color='b')
axes[0].set_title('Distribution of SkinThickness',fontdict={'fontsize':8})
axes[0].set_xlabel('SkinThickness Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('SkinThickness',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %%
# Skin Thickness = 0
skinThicknessNol = (df['SkinThickness'] == 0).sum()
print("Data SkinThickness 0 =", skinThicknessNol)

# Skin Thickness Outlier > 80
skinThicknessOutlier = (df['SkinThickness'] > 80).sum()
print("Data SkinThickness outlier > 80 =", skinThicknessOutlier)
# Out:
# Data SkinThickness 0 = 227
# Data SkinThickness outlier > 80 = 1

# %%
df = df.loc[df['SkinThickness'] < 80 ]
df.SkinThickness = df.SkinThickness.replace(0,df.SkinThickness.mean())
print(df['SkinThickness'].describe())
# Out:
# count    759.000000
# mean      26.406023
# std        9.311032
# min        7.000000
# 25%       20.326746
# 50%       23.000000
# 75%       32.000000
# max       63.000000
# Name: SkinThickness, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['SkinThickness'],ax=axes[0],color='b')
axes[0].set_title('Distribution of SkinThickness',fontdict={'fontsize':8})
axes[0].set_xlabel('SkinThickness Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('SkinThickness',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %% [markdown]
# ## E. Kolom Insulin

# %%
df.Insulin.describe()
# Out:
# count    759.000000
# mean      79.777339
# std      115.751482
# min        0.000000
# 25%        0.000000
# 50%       23.000000
# 75%      128.500000
# max      846.000000
# Name: Insulin, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['Insulin'],ax=axes[0],color='b')
axes[0].set_title('Distribution of Insulin',fontdict={'fontsize':8})
axes[0].set_xlabel('Insulin Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('Insulin',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %%
# Menghitung banyaknya data insulin bernilai 0
InsulinNol = (df['Insulin'] == 0).sum()
print("Data Insulin 0 =", InsulinNol)

# Menghitung banyaknya data insulin bernilai > 600 karena dianggap outlier
InsulinOutlier = (df['Insulin'] > 600).sum()
print("Data Insulin >600 =", InsulinOutlier)
# Out:
# Data Insulin 0 = 372
# Data Insulin >600 = 3

# %%
# Memasukkan data yang negatif ke df0
df0 = df.loc[df['Outcome'] == 0 ].copy()
# Memasukkan data yang positif ke df1
df1 = df.loc[df['Outcome'] == 1 ].copy()

# Mengganti data bernilai 0 dalam df0 dengan nilai rata-rata dari outcoume negatif
df0.Insulin = df0.Insulin.replace(0, df0.Insulin.mean())
# Mengganti data bernilai 0 dalam df1 dengan nilai rata-rata dari outcoume positif
df1.Insulin = df1.Insulin.replace(0, df1.Insulin.mean())

# Menyatukan kembali nilai df0 dan df1 ke df
df.drop(df.index, inplace=True)
df = df0.append(df1)

# Menghapus outlier
df = df.loc[df['Insulin'] <= 600 ]

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['Insulin'],ax=axes[0],color='b')
axes[0].set_title('Distribution of Insulin',fontdict={'fontsize':8})
axes[0].set_xlabel('Insulin Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('Insulin',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %%
df.Insulin.describe()
# Out:
# count    756.000000
# mean     116.667508
# std       85.034260
# min       14.000000
# 25%       68.748491
# 50%      100.000000
# 75%      126.250000
# max      600.000000
# Name: Insulin, dtype: float64

# %% [markdown]
# ## F. Kolom BMI

# %%
df.BMI.describe()
# Out:
# count    756.000000
# mean      31.903571
# std        7.834561
# min        0.000000
# 25%       27.275000
# 50%       32.000000
# 75%       36.500000
# max       67.100000
# Name: BMI, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['BMI'],ax=axes[0],color='b')
axes[0].set_title('Distribution of BMI',fontdict={'fontsize':8})
axes[0].set_xlabel('BMI Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('BMI',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %%
# Menghitung banyaknya data BMI bernilai 0
BMINol = (df['BMI'] == 0).sum()
print("Data BMI 0 =", BMINol)
# Out:
# Data BMI 0 = 11

# %%
df.BMI = df.BMI.replace(0,df.BMI.mean())
print(df['BMI'].describe())
# Out:
# count    756.000000
# mean      32.367777
# std        6.806992
# min       18.200000
# 25%       27.500000
# 50%       32.000000
# 75%       36.500000
# max       67.100000
# Name: BMI, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['BMI'],ax=axes[0],color='b')
axes[0].set_title('Distribution of BMI',fontdict={'fontsize':8})
axes[0].set_xlabel('BMI Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('BMI',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %% [markdown]
# ## G. Diabetes Pedigree Function

# %%
df.DiabetesPedigreeFunction.describe()
# Out:
# count    756.000000
# mean       0.470149
# std        0.326213
# min        0.078000
# 25%        0.243750
# 50%        0.369000
# 75%        0.627500
# max        2.420000
# Name: DiabetesPedigreeFunction, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['DiabetesPedigreeFunction'],ax=axes[0],color='b')
axes[0].set_title('Distribution of DPF',fontdict={'fontsize':8})
axes[0].set_xlabel('DPF Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('DiabetesPedigreeFunction',data=df,ax=axes[1],orient = 'v',color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %% [markdown]
# ## H. Kolom Age

# %%
df.Age.describe()
# Out:
# count    756.000000
# mean      33.166667
# std       11.722453
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       40.250000
# max       81.000000
# Name: Age, dtype: float64

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,dpi=120,figsize = (8,4))

plot00=sns.distplot(df['Age'],ax=axes[0],color='b')
axes[0].set_title('Distribution of Age',fontdict={'fontsize':8})
axes[0].set_xlabel('Age Class',fontdict={'fontsize':7})
axes[0].set_ylabel('Frequency/Distrubtion',fontdict={'fontsize':7})
plt.tight_layout()

plot01=sns.boxplot('Age',data=df,ax=axes[1],orient = 'v', color='c')
axes[1].set_title('Five Point Summary',fontdict={'fontsize':8})
plt.tight_layout()

# %%
print(df.shape)
df.head()
# Out:
# (756, 9)
#     Pregnancies  Glucose  BloodPressure  SkinThickness    Insulin   BMI  \
# 1             1     85.0      66.000000      29.000000  68.748491  26.6
# 3             1     89.0      66.000000      23.000000  94.000000  28.1
# 5             5    116.0      74.000000      20.326746  68.748491  25.6
# 7            10    115.0      69.098168      20.326746  68.748491  35.3
# 10            4    110.0      92.000000      20.326746  68.748491  37.6
#
#     DiabetesPedigreeFunction  Age  Outcome
# 1                      0.351   31        0
# 3                      0.167   21        0
# 5                      0.201   30        0
# 7                      0.134   29        0
# 10                     0.191   30        0

# %%
df.info()
df.var()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 756 entries, 1 to 766
# Data columns (total 9 columns):
# Pregnancies                 756 non-null int64
# Glucose                     756 non-null float64
# BloodPressure               756 non-null float64
# SkinThickness               756 non-null float64
# Insulin                     756 non-null float64
# BMI                         756 non-null float64
# DiabetesPedigreeFunction    756 non-null float64
# Age                         756 non-null int64
# Outcome                     756 non-null int64
# dtypes: float64(6), int64(3)
# memory usage: 59.1 KB
# Pregnancies                   10.788514
# Glucose                      906.936613
# BloodPressure                138.891493
# SkinThickness                 86.756339
# Insulin                     7230.825365
# BMI                           46.335147
# DiabetesPedigreeFunction       0.106415
# Age                          137.415894
# Outcome                        0.226348
# dtype: float64

# %%
df.Outcome.value_counts()
# Out:
# 0    495
# 1    261
# Name: Outcome, dtype: int64

# %%
sns.countplot(df['Outcome']).set_title('Distribution of Outcome')
plt.show()

# %%
df.to_csv ('input/diabetesPreProcessed.csv', index = False, header=True)
